# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('menu.csv')
df
# Out:
#                                                      Link  \
# 0       https://www.foody.vn/ho-chi-minh/tra-sua-tiger...
# 1       https://www.foody.vn/ho-chi-minh/tra-sua-tiger...
# 2       https://www.foody.vn/ho-chi-minh/tra-sua-tiger...
# 3       https://www.foody.vn/ho-chi-minh/tra-sua-tiger...
# 4       https://www.foody.vn/ho-chi-minh/tra-sua-tiger...
# ...                                                   ...
# 519765  https://www.foody.vn/ho-chi-minh/che-khuc-bach...
# 519766  https://www.foody.vn/ho-chi-minh/che-khuc-bach...
# 519767  https://www.foody.vn/ho-chi-minh/che-khuc-bach...
# 519768  https://www.foody.vn/ho-chi-minh/lau-bo-xuan-h...
# 519769  https://www.foody.vn/ho-chi-minh/lau-bo-xuan-h...
#
#                                                 Food_Name   Price     district
# 0                                    Hổ Vàng Hạt Chia (L)   41000       Quận 1
# 1                             Đường Nâu Trân Châu Sữa (M)   51000       Quận 1
# ...

# %%
df.to_csv("menu.csv", index=False, header=True)

# %%
f = open('food_name.txt', 'w', encoding="utf-8")

for i in list(df[df['Price']<=5000].index):
    f.write("{}\t\t{}\n".format(str(i),df.loc[i]['Food_Name']))
    
f.close()

# %%
df = df.drop(labels = idx, axis=0)

# %%
df_ = df[df['Price']>=5000]

# %%
df_
# Out:
#                                                      Link  \
# 0       https://www.foody.vn/ho-chi-minh/tra-sua-tiger...
# 1       https://www.foody.vn/ho-chi-minh/tra-sua-tiger...
# 2       https://www.foody.vn/ho-chi-minh/tra-sua-tiger...
# 3       https://www.foody.vn/ho-chi-minh/tra-sua-tiger...
# 4       https://www.foody.vn/ho-chi-minh/tra-sua-tiger...
# ...                                                   ...
# 519765  https://www.foody.vn/ho-chi-minh/che-khuc-bach...
# 519766  https://www.foody.vn/ho-chi-minh/che-khuc-bach...
# 519767  https://www.foody.vn/ho-chi-minh/che-khuc-bach...
# 519768  https://www.foody.vn/ho-chi-minh/lau-bo-xuan-h...
# 519769  https://www.foody.vn/ho-chi-minh/lau-bo-xuan-h...
#
#                                                 Food_Name   Price     district
# 0                                    Hổ Vàng Hạt Chia (L)   41000       Quận 1
# 1                             Đường Nâu Trân Châu Sữa (M)   51000       Quận 1
# ...

# %%
df_.to_csv("menu_drop_5K.csv", index=False, header=True)

# %%
df
# Out:
#                                                      Link  \
# 0       https://www.foody.vn/ho-chi-minh/tra-sua-tiger...
# 1       https://www.foody.vn/ho-chi-minh/tra-sua-tiger...
# 2       https://www.foody.vn/ho-chi-minh/tra-sua-tiger...
# 3       https://www.foody.vn/ho-chi-minh/tra-sua-tiger...
# 4       https://www.foody.vn/ho-chi-minh/tra-sua-tiger...
# ...                                                   ...
# 519765  https://www.foody.vn/ho-chi-minh/che-khuc-bach...
# 519766  https://www.foody.vn/ho-chi-minh/che-khuc-bach...
# 519767  https://www.foody.vn/ho-chi-minh/che-khuc-bach...
# 519768  https://www.foody.vn/ho-chi-minh/lau-bo-xuan-h...
# 519769  https://www.foody.vn/ho-chi-minh/lau-bo-xuan-h...
#
#                                                 Food_Name   Price     district
# 0                                    Hổ Vàng Hạt Chia (L)   41000       Quận 1
# 1                             Đường Nâu Trân Châu Sữa (M)   51000       Quận 1
# ...
