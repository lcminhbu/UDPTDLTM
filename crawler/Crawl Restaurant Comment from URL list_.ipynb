# %% [markdown]
# # Library

# %%
from pymongo import MongoClient

import threading
from threading import Lock
from threading import Thread

from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from webdriver_manager.microsoft import EdgeChromiumDriverManager

import time
import json
import numpy as np
import pandas as pd
from pprint import pprint
from datetime import datetime

# %% [markdown]
# # Global Variables

# %%
wait_time = 2
load_time = 2

comment = {
    "Via": "",
    "Date Time": "",
    "Summary": "",
    "Full Content": "",
    "Rating": "",
}

record = {
    "index": "",
    "_id": "",
    "URL": "",
    "Comments": []
}

CONNECTION_STRING = "mongodb+srv://username:Password123@udptdltm-data.ocmcsqz.mongodb.net/test"
db = MongoClient(CONNECTION_STRING)

# Store links Dataframe
store_links = db["udptdltm-database"]["store_links"]
df = pd.DataFrame.from_records(list(store_links.find({})))

# Store Comment MongoDB collections
db_ = MongoClient("mongodb+srv://analytics:analytics-password@cluster0.orpccey.mongodb.net/?retryWrites=true&w=majority")
cmt_col = db_.UDPTDLTM.Comments_29K_Official

#cmt_col = db["udptdltm-database"]["Comments"]

# %% [markdown]
# ## Get Restaurant URL list

# %%
df.head()
# Out:
#                         _id                                store_name  \
# 0  63442aa9a4a40c2b14b7576c                             Bún Bò Huế 31
# 1  63442aa9a4a40c2b14b7576d     Cơm Tấm Bụi Sài Gòn - Thạch Thị Thanh
# 2  63442aa9a4a40c2b14b75779             Jumbo Seafood - Trần Hưng Đạo
# 3  63442aa9a4a40c2b14b75784                          BOC Homemade BBQ
# 4  63442aa9a4a40c2b14b75785  Nhà Hàng Hàn Quốc Choi Go Jip - Hàm Nghi
#
#                                                 href
# 0     https://www.foody.vn/ho-chi-minh/bun-bo-hue-31
# 1  https://www.foody.vn/ho-chi-minh/com-tam-bui-s...
# 2  https://www.foody.vn/ho-chi-minh/jumbo-seafood...
# 3  https://www.foody.vn/ho-chi-minh/boc-homemade-bbq
# 4  https://www.foody.vn/ho-chi-minh/nha-hang-han-...

# %% [markdown]
# # Functions

# %%
def checkCommentSection(driver1):
    try:
        driver1.find_element_by_xpath("//div[@class='lists list-reviews']")
    except:
        return False
    return True  
    
def crawlComments(url_, driver2):
    cmt_list = []
    
    driver2.get(url_)
    time.sleep(load_time)
    
    if checkCommentSection(driver2)==False:
        return cmt_list
    else:
        # Load all comments by clicking "Show More" button.
        for i in range(2):
            try:
                driver2.find_element_by_xpath("//div[@class='lists list-reviews']/div/div").click()
                time.sleep(1)
            except:
                break
        try:        
            cmts = driver2.find_elements_by_xpath("//div[@class='lists list-reviews']/div/ul/li[@class='review-item fd-clearbox ng-scope']")
        except:
            return cmt_list
        
        for elem in cmts:
            cmt = comment.copy()
            
            try:
                dt = elem.find_element_by_xpath('./div/div[2]/div[@class="ru-stats"]/span').text
                datetime_ = datetime.strptime(dt, "%d/%m/%Y %H:%M")
                
                if datetime_.year < 2021:
                    return cmt_list
                
                cmt["Date Time"] = datetime_
            except:
                cmt['Date Time'] = "None"  
                
            try:
                cmt['Via'] = elem.find_element_by_xpath('./div/div[2]/div[@class="ru-stats"]/a').text.replace("via ", "")
            except:
                cmt['Via'] = "None"
                
            try:
                cmt["Summary"] = elem.find_element_by_xpath('./div[2]/a').text
            except:
                cmt['Summary'] = "None"
            
            try: 
                cmt["Full Content"] = elem.find_element_by_xpath('./div[2]/div/span').text
            except:
                cmt['Full Content'] = "None"
                
            try:
                r = elem.find_element_by_xpath('./div/div[2]/div/span').text
                cmt["Rating"] = float(r)
            except:
                cmt['Rating'] = "None"
                
            cmt_list.append(cmt)
    return cmt_list

def crawlStore(index, id_, url_, driver3):
    rec = record.copy()
    
    rec['index'] = index
    rec['_id'] = id_
    rec['URL'] = url_
    try:
        rec['Comments'] = crawlComments(url_, driver3)
    except:
        print("Cant crawl comment for {}".format(index))
        rec['Comments'] = []
    
    #print(str(index) + " Done.")
    
    return rec

# %% [markdown]
# ## Thread

# %%
thread_lock = Lock()

def thread(df1, collection):
    
    #driver_ = webdriver.Chrome(ChromeDriverManager().install())
    # driver_ = webdriver.Edge(EdgeChromiumDriverManager().install())
    driver_ = webdriver.Chrome()
    
    df_ = df1.copy()
    
    for i in df_.index:
        id_ = df_.loc[i]['_id']
        url_ = df_.loc[i]['href']
        
        t = crawlStore(i, id_, url_, driver_)
        
        try:
            collection.insert_one(t)
            print("Inserted {}".format(i))
            
            thread_lock.acquire()
            thread_lock.release()
        except:
            print("Error while adding document at index {} to collection.".format(i))
            continue
        time.sleep(1)
    driver_.close()
    return 1

def multi_thread_get_cmts(from_index, to_index, thread_nums=10, df_=df, collection=cmt_col, thread=thread, sleep_time=1):
    # Tham số:
    # from_index: Index của dòng đầu tiên (chiếu theo index của dataframe df).
    # to_index: Index của dòng cuối cùng (chiếu theo index của dataframe df).
    # thread_nums: Số lượng thread cần tạo.
    # df_: Dataframe các cửa hàng, mặc định là Dataframe df trong phần Global Variable phía trên.
    # collection: Collection sẽ được lưu, mặc định là cmt_col.
    # thread: Hàm cần chạy thread.
    # sleep_time: Thời gian dừng.
    
    
    #df_ = df[(df.index>=from_index) & (df.index<=to_index)]
    temp = np.array_split(range(from_index, to_index+1), thread_nums)
    
    dfs = [df_[(df_.index>=i[0]) & (df_.index<=i[-1])] for i in temp if len(i)!=0]
    
    print("----------------Start----------------")
    for d in dfs:
        th = Thread(target=thread, args=[d, collection])
        time.sleep(1)
        th.start()
            
    #print("----------------Done----------------")

# %% [markdown]
# # Hướng dẫn chạy

# %% [markdown]
# - Hướng dẫn chạy:
#     - Bước 1: **MỌI NGƯỜI** chạy các ô phía trên ô này.
#     - Bước 2: Chạy hàm **multi_thread_get_cmts(9, 10)**. Trong đó:
#         - from_index = 9: Bắt đầu từ dòng có index 9 trong dataframe df.
#         - to_index = 10: Kết thúc ở dòng có index 10 trong dataframe df.
#         - Các tham số còn lại đã mặc định, thay đổi nếu cần thiết.
#
# - Lưu ý:
#     - Sau mỗi lần chạy hàm, nên note lại chỉ số index đầu cuối mà mình đã crawl vào file: https://studenthcmusedu-my.sharepoint.com/personal/19120462_student_hcmus_edu_vn/_layouts/15/onedrive.aspx?ga=1&fbclid=IwAR0%2DJVtQBk2dcJeDwNnLdMBc%2DeR8ALh7ls5%5FY%5FkTCh5A4pX5ECNjQWnguqA&id=%2Fpersonal%2F19120462%5Fstudent%5Fhcmus%5Fedu%5Fvn%2FDocuments%2FUDPTDLTM%2FPh%C3%A2n%20c%C3%B4ng%2Etxt&parent=%2Fpersonal%2F19120462%5Fstudent%5Fhcmus%5Fedu%5Fvn%2FDocuments%2FUDPTDLTM
#     hoặc file nào đó khác để tránh tình trạng bị trùng (Hàm sẽ báo lỗi nếu bị trùng) và cần chỉ rõ là mình crawl phần nào.
#     VD: Comment - Thái - 0-100
#     - Phân công như sau:
#         Đăng: 0->5804
#         Thái: 5805->11609
#         Duy: 11610->17414
#         Thắng: 17415->23219
#         Bửu: 23220->29024
#         (Đây là chỉ số index trong DataFrame)
#     - Đôi khi hàm xuất thông báo lỗi như sau:
#         - "Can't crawl comments for {index}".
#         - "Error while adding document at index {} to collection."
#         - Thì bạn nên lưu lại những index này, sau khi hàm chạy xong thì có thể kiểm tra lại bằng MongoDB Compass cho nhanh.

# %% [markdown]
# # DEMO

# %% [markdown]
# - Đây là Demo chạy thử và lưu lại trên Database của Thái nên các ông test thoải mái nhưng đừng đụng đến collections "Comments_2"

# %% [markdown]
# db_ = MongoClient("mongodb+srv://analytics:analytics-password@cluster0.orpccey.mongodb.net/?retryWrites=true&w=majority")
# my_collections_ = db_.UDPTDLTM.Comments_29K_tests
#
# multi_thread_get_cmts(11, 12, 10, df, my_collections_)

# %% [markdown]
# # Start Crawl

# %% [markdown]
# - Unmarked below cell to start crawling. Remember to specify from_index and to_index, thread_nums is Optional.

# %%
from_index_ = 25220
to_index_ = 27220
thread_nums_ = 7

multi_thread_get_cmts(from_index_, to_index_, thread_nums_)
# Out:
# ----------------Start----------------
# Inserted 26364
# Inserted 25506
# Inserted 26936
# Inserted 26078
# Inserted 25792
# Error while adding document at index 25220 to collection.
# Inserted 26365
# Inserted 26079
# Inserted 25221
# Inserted 25507
# Inserted 25793
# Inserted 26366
# Inserted 26937
# Inserted 25222
# Inserted 25794
# Inserted 26650
# Inserted 26938
# Inserted 26367
# Inserted 25795
# Inserted 26368
# Inserted 25223
# Inserted 25796
# Inserted 26369
# Inserted 25797
# Inserted 26370
# Inserted 25224
# Inserted 25508
# Inserted 26651
# Inserted 26371
# Inserted 25798
# Inserted 26080
# Inserted 26372
# Inserted 25509
# Inserted 26373
# Inserted 26652
# Inserted 25510
# Inserted 26374
# Inserted 26939
# Inserted 26375
# Inserted 26376
# Inserted 25225
# Inserted 26653
# Inserted 26081
# Inserted 25511
# Inserted 26940
# Inserted 26377
# Inserted 26378
# Inserted 26654
# Inserted 26379
# Inserted 26941
# Inserted 26082
# Inserted 26380
# Inserted 25799
# Inserted 25512
# Inserted 26381
# Inserted 26083
# Inserted 26382
# Inserted 26383
# Inserted 25800
# Inserted 26384
# Inserted 25226
# Inserted 26385
# Inserted 25801
# Inserted 25227
# Inserted 26386
# Inserted 25513
# Inserted 25802
# Inserted 26942
# Inserted 26655
# Inserted 26084
# Inserted 26387
# Inserted 25514
# Inserted 25803
# Inserted 26085
# Inserted 25228
# Inserted 25515
# Inserted 26388
# Inserted 25229
# Inserted 26943
# Inserted 25804
# Inserted 26656
# Inserted 26086
# Inserted 26389
# Inserted 25516
# Inserted 26944
# Inserted 25230
# Inserted 26324
# Inserted 25481
# Inserted 25781
# Inserted 27218
# Inserted 26840
# Inserted 27219
# Inserted 25782
# Inserted 25482
# Inserted 26841
# Inserted 25783
# Inserted 25483
# Inserted 26325
# Inserted 26842
# Inserted 25784
# Inserted 25484
# Inserted 26326
# Inserted 27220
# Inserted 25785
# Inserted 26843
# Inserted 25786
# Inserted 26327
# Inserted 25485
# Inserted 25787
# Inserted 26328
# Inserted 25486
# Inserted 25788
# Inserted 26844
# Inserted 25487
# Inserted 25789
# Inserted 26845
# Inserted 26329
# Inserted 25488
# Inserted 25790
# Inserted 26846
# Inserted 25791
# Inserted 26330
# Inserted 25489
# Inserted 26331
# Inserted 25490
# Inserted 26847
# Inserted 26332
# Inserted 25491
# Inserted 26333
# Inserted 25492
# Inserted 26334
# Inserted 26848
# Inserted 26335
# Inserted 25493
# Inserted 26849
# Inserted 26336
# Inserted 25494
# Inserted 26850
# Inserted 26337
# Inserted 25495
# Inserted 26338
# Inserted 26851
# Inserted 25496
# Inserted 25497
# Inserted 26339
# Inserted 26852
# Inserted 25498
# Inserted 26340
# Inserted 26853
# Inserted 26341
# Inserted 25499
# Inserted 26342
# Inserted 26854
# Inserted 26343
# Inserted 26855
# Inserted 25500
# Inserted 26344
# Inserted 26856
# Inserted 25501
# Inserted 26857
# Inserted 26858
# Inserted 26345
# Inserted 25502
# Inserted 26346
# Inserted 26859
# Inserted 25503
# Inserted 26347
# Inserted 26860
# Inserted 25504
# Inserted 26348
# Inserted 26349
# Inserted 26861
# Inserted 25505
# Inserted 26862
# Inserted 26350
# Inserted 26863
# Inserted 26351
# Inserted 26864
# Inserted 26352
# Inserted 26865
# Inserted 26353
# Inserted 26866
# Inserted 26354
# Inserted 26355
# Inserted 26867
# Inserted 26356
# Inserted 26868
# Inserted 26357
# Inserted 26869
# Inserted 26358
# Inserted 26870
# Inserted 26871
# Inserted 26359
# Inserted 26872
# Inserted 26360
# Inserted 26361
# Inserted 26362
# Inserted 26363
# Inserted 26873
# Inserted 26874
# Inserted 26875
# Inserted 26876
# Inserted 26877
# Inserted 26878
# Inserted 26879
# Inserted 26880
# Inserted 26881
# Inserted 26882
# Inserted 26883
# Inserted 26884
# Inserted 26885
# Inserted 26886
# Inserted 26887
# Inserted 26888
# Inserted 26889
# Inserted 26890
# Inserted 26891
# Inserted 26892
# Inserted 26893
# Inserted 26894
# Inserted 26895
# Inserted 26896
# Inserted 26897
# Inserted 26898
# Inserted 26899
# Inserted 26900
# Inserted 26901
# Inserted 26902
# Inserted 26903
# Inserted 26904
# Inserted 26905
# Inserted 26906
# Inserted 26907
# Inserted 26908
# Inserted 26909
# Inserted 26910
# Inserted 26911
# Inserted 26912
# Inserted 26913
# Inserted 26914
# Inserted 26915
# Inserted 26916
# Inserted 26917
# Inserted 26918
# Inserted 26919
# Inserted 26920
# Inserted 26921
# Inserted 26922
# Inserted 26923
# Inserted 26924
# Inserted 26925
# Inserted 26926
# Inserted 26927
# Inserted 26928
# Inserted 26929
# Inserted 26930
# Inserted 26931
# Inserted 26932
# Inserted 26933
# Inserted 26934
# Inserted 26935
